# %% [markdown]
# This file converts the raw data into alarms. 1 line of the output file represent 1 alarm.

# %%
# import json
import pandas as pd
from datetime import datetime, timedelta
from dateutil.parser import parse # to convert string date to pyton Date type so that we can compare dates with each other
# from pathlib import Path
import glob # to get the names and paths of the files in a directory/folder

# %% [markdown]
# # 1. Class which Convert records csv to into alarms

# %%
# format csvs

class CSV2Alarms:
    """
        Summary:
        Record mean 1 row of the csv file. 
        This class converts records into alarms. 
    """
    def __init__(self,config): #done
        self.config = config
        print(f'>>Input file: {self.config["dir"]+self.config["in_fname"]}')
         
        self.df = None
        # reading raw csv fiile
        try:
            self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], delimiter= ";" , usecols=self.config["cols"], encoding = "ISO-8859-1")
        except Exception as e:
            print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion 1  {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")
            a = 1
        
        try:
            self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], delimiter= "," , usecols=self.config["cols"], encoding = "ISO-8859-1")
        except Exception as e:
            a =1
            # self.df = pd.read_csv(self.config["dir"]+self.config["in_fname"], encoding = "ISO-8859-1")
            print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion 2 {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")
        print(">>File is read.")

    # removing the extra chars and returning the python Date   
    def __changeDate(self,d): # done
        d = d.replace(".000000000","") # removing extra zeros from the string date
        d = d.replace("/","-") 
        return parse(d) # converting string to a python Date type e.g., float('5')

    # Returning the alarm message type
    def __getMessageType(self,message): # done
        if message.find("Recover") != -1:  # finding the deactivation message
            return "Recover"
        elif message.find("NR") != -1: 
            return "NR"
        else:
            return "Activation" 
    
    def __getAlarmsFromDFs(self,df_start, df_end): # done
        alarms = []
        start_records = [v for v in sorted(df_start.to_dict(orient="records"), key=lambda arg: arg["EventTime"], reverse=False)] # sortting the dataframes rows in ascending order and storing them in a list
        end_records = [v for v in sorted(df_end.to_dict(orient="records"), key=lambda arg: arg["EventTime"], reverse=False)]

        i = 0
        j = 0
        # print("End len",len(end_records), "Start len", len(start_records))

        while j < len(end_records): # ingore the row/entry if the end time is lesser to start time
            # print(i,j)
            if len(start_records)>0 and end_records[j]["EventTime"] < start_records[i]["EventTime"]:
                j += 1
            else:
                break

        while i < len(start_records): # find the one to one correspondence between startingtime and its coressponding most recent end time.
            
            if j <len(end_records) and start_records[i]["EventTime"] <= end_records[j]["EventTime"]:
                if i+1 < len(start_records) and start_records[i+1]["EventTime"] < end_records[j]["EventTime"]: # check for the next record
                    i += 1
                    continue
                alarm = {k: v for k, v in start_records[i].items()} # an alarm dictionary
                alarm["StartTime"] = alarm["EventTime"]
                alarm["EndTime"] = end_records[j]["EventTime"]
                alarm["EndMessage"] = end_records[j]["Message"]
                del alarm["EventTime"]
                alarms.append(alarm)
                j += 1
            elif j <len(end_records) and start_records[i]["EventTime"] > end_records[j]["EventTime"]:
                j +=1
                continue   
                
            i += 1

        return alarms
    
    def __convertRecordsToAlarmsV1(self,df_source): # done 
        """ Convert records from the same source to proper alarms with start and end time.   

            The record which contains "Recover" or "NR" in the Message column shows the deactivations. 

        Parameters
        ----------
        records : list of dict
            Each dict represent either activation of an alarm or deactivation of an alarm.  

        Returns
        -------
        alarms : list of dict
            Each dict in the list is an alarm with the StartTime and EndTime of an alarm. 
        """
        alarms = []
        for condition in df_source["Condition"].unique():
            df_condition = df_source.loc[df_source['Condition'].isin([condition])]
            df_start = df_condition.loc[df_condition['MessageType'].isin([
                                                                        "Activation"])]
            end_types = [t for t in df_condition["MessageType"].unique() if t !=
                    "Activation"] # NR, Recover, NR+Reocver
            # print(types)
            df_end = df_condition.loc[df_condition['MessageType'].isin(end_types)]
            alarms += self.__getAlarmsFromDFs(df_start, df_end)
        return alarms
    
    
    def formatCSV(self): # done
        file = in_config["dir"] + in_config["formated_fname"]
        import os  
        os.makedirs(file, exist_ok=True)
        
        print(">>Column  Types: ", end="")
        for col in self.df.columns:
            print(col, type(self.df[col][0]), end=", ")
            if isinstance(self.df[col][0],str):
                try:
                    self.df[col] = self.df[col].apply(lambda s: " ".join(s.split())) # removing the extra spaces in a column 
                except Exception as e:
                    print(f"\n\n !!!!!!!!!!!!!!!!!! Excetpion {e} !!!!!!!!!!!!!!!!!!!!!!!!!!")

        print(type(self.df["EventTime"][0]))
        self.df["EventTime"] = self.df["EventTime"].apply(self.__changeDate)
        self.df["MessageType"] = self.df["Message"].apply(self.__getMessageType)
        # self.df["Month"] = self.df["EventTime"].apply(lambda arg: arg.month)
        print(f">>Before Filtering ACKS: {self.df.shape}")
        self.df = self.df.loc[self.df['Message'].map(lambda arg: arg.find(self.config["ack-filter"])) == -1]  # removing the Acknowledgements
        print(f">>After Filtering ACKS: {self.df.shape}") 
        

        fpath = self.config["dir"] + self.config["formated_fname"] + formated_csv
        self.df.to_csv(fpath, index=False) # storing pandas dataframe into a csv file
        return self.df
    
    def readFormattedCSV(self): # done
        fpath = self.config["dir"] + self.config["formated_fname"]+ formated_csv
        self.df = pd.read_csv(fpath, low_memory=False, parse_dates=["EventTime"])
        print(f">> Formating is complete. Outfile: {fpath}")
        return self.df

    def convertRecords2Alarms(self,df): # done
        # df = pd.read_csv(p, low_memory=False, usecols=cols,parse_dates=["EventTime"])
        

        assert len(df["MachineName"].unique()) == 1 # all the alarms should be related to the same unit
        
        alarms = []
        sources_ranks_dict = df['SourceName'].value_counts()
        id = 0 # for debugging
        for sname in sources_ranks_dict.keys(): # for each source find the activation and deactivation times and covert them to alarms
            id += 1
            # TIC4544
            df_sname = df.loc[df['SourceName'].isin([sname])] # source DF
            # types_rank_dict = df_sname["MessageType"].value_counts() # source ranks
            # total = 0
            # for key in types_rank_dict.keys():
            #     total += types_rank_dict[key]
            # assert(total== sources_ranks_dict[sname]) # sum is equal to count 
            print(f"Test:{sname}")
            source_alarms = self.__convertRecordsToAlarmsV1(df_sname) # getting alarms related to one source (sname)
            print("end")
            alarms += source_alarms
        
            print(f"[{id}]Source:{sname}, Conditions:{df_sname['Condition'].unique()}, Total Alarms:{len(source_alarms)}")

        df_out = pd.DataFrame(alarms)
        df_out["TimeDelta"] = df_out[["StartTime", "EndTime"]].apply(lambda arg: timedelta.total_seconds(arg[1]-arg[0]) , axis=1)
        df_out["Year-Month"] =df_out["StartTime"].apply(lambda arg: (arg.year,arg.month))

        file_path = self.config["dir"]+self.config["alarm_out_fname"] + alarm_out 
        df_out.to_csv(file_path, index = False)
        print(f">>Conversion from records to alarms is complete. Outputfile : {file_path}, Info : {df_out.info()}")
        return df_out

# %%
# def getPlantShutDownPeriods(filepath):
#     df_feed = pd.read_excel(filepath)
    
#     feed_records = [v for v in sorted(df_feed.to_dict(orient="records"), key=lambda arg: arg["TimeStamp"], reverse=False)]
#     plant_shut_down_periods = []

#     start_time = None
#     start_flag = True

#     for i in range(len(feed_records)):
#         if feed_records[i]["47FIC011.PV"] <=50 and start_flag ==True:
#             start_time = feed_records[i]["TimeStamp"]
#             start_flag = False
#             # print(f"{start_time},{feed_records[i]['47FIC011.PV']}  ", end=" ")
#         elif feed_records[i]["47FIC011.PV"] >50 and i>0 and feed_records[i-1]["47FIC011.PV"]<=50:
#             plant_shut_down_periods.append((start_time,feed_records[i]["TimeStamp"])) 
#             start_flag =True
#             # print(f'{feed_records[i]["TimeStamp"]},{feed_records[i-1]["47FIC011.PV"]},{feed_records[i]["47FIC011.PV"]}')


#     return plant_shut_down_periods



# def monthlyAlarms2SingleFile(config):
#     alarms_dir, out_file_path ,cols = config["dir"], config["out_file"], config['cols']
#     fps = [f for f in glob.glob(alarms_dir+ "*.csv")]
#     print(f">> Files to process {fps}")
#     dfs_list = []
#     for f in fps:
#         print(f">> === File: {f.split('/')[-1]}")
#         df = pd.read_csv(f, usecols = cols ,parse_dates = ["StartTime","EndTime"])
#         dfs_list.append(df)

#     df = pd.concat(dfs_list, ignore_index=True)
#     df.to_csv(out_file_path, index=False)
#     return df

# %% [markdown]
# # 2. Configuration of input dirs and output dirs and file names

# %%
ACK_FILTER = "ACK"
# PLANT = "plant_33"
in_config = {
    "dir": "/Users/hamzagorgulu/Desktop/thesis/Waris Final/tupras/data/processed/alarms/final/",
    "csv_names" : "final-all-months-alarms-with-day-filtered.csv", 
    "in_fname": None, # input file name
    "formated_fname":  None, 
    "alarm_out_fname": None, 
    "ack-filter":ACK_FILTER,
    'cols':["MachineName","SourceName","EventTime", "Message","Condition"]

}

print(in_config)
# Out:
# {'dir': '/Users/hamzagorgulu/Desktop/thesis/Waris Final/tupras/data/processed/alarms/final/', 'csv_names': 'final-all-months-alarms-with-day-filtered.csv', 'in_fname': None, 'formated_fname': None, 'alarm_out_fname': None, 'ack-filter': 'ACK', 'cols': ['MachineName', 'SourceName', 'EventTime', 'Message', 'Condition']}

# %%
alarm = None
temp_df = None
obj = None
# for f in in_config["csv_names"]:

#     in_config['in_fname'] =  "raw/"+f
#     in_config['formated_fname'] = "raw/formatted_"+f
#     in_config["alarm_out_fname"] = "alarms/alarms_"+f
#     obj  = CSV2Alarms(in_config)
#     temp_df = obj.formatCSV()
    
formated_csv = "formated.csv"
alarm_out = "alarm_out.csv"
in_config['in_fname'] =  in_config["csv_names"]
in_config['formated_fname'] = "raw/formatted_/"
in_config["alarm_out_fname"] = "alarms/alarms_/"

# %%
# add paths
file1 = in_config["dir"] + in_config["alarm_out_fname"]
import os  
os.makedirs(file1, exist_ok=True)

file2 = in_config["dir"] + in_config["formated_fname"]
import os  
os.makedirs(file2, exist_ok=True)

# %%
obj = CSV2Alarms(in_config)
# Out:
# >>Input file: /Users/hamzagorgulu/Desktop/thesis/Waris Final/tupras/data/processed/alarms/final/final-all-months-alarms-with-day-filtered.csv
#
#
#  !!!!!!!!!!!!!!!!!! Excetpion 1  Usecols do not match columns, columns expected but not found: ['EventTime', 'SourceName', 'MachineName', 'Condition', 'Message'] !!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#  !!!!!!!!!!!!!!!!!! Excetpion 2 Usecols do not match columns, columns expected but not found: ['EventTime'] !!!!!!!!!!!!!!!!!!!!!!!!!!
# >>File is read.

# %%
temp_df = obj.formatCSV()
# Out:
# >>Column  Types: MachineName <class 'str'>, SourceName <class 'str'>, EventTime <class 'str'>, Message <class 'str'>, Condition <class 'str'>, <class 'str'>
# >>Before Filtering ACKS: (1944109, 6)
# >>After Filtering ACKS: (1938898, 6)

# %%
temp_df = obj.readFormattedCSV()
# Out:
# >> Formating is complete. Outfile: J:/GENEL MUDURLUK/ARGE MUDURLUGU/ALGORİTMA-VE-YAZILIMSAL-ÇÖZÜM-GELİŞTİRME/1. PROJELER/10. KUTEM/3- VERİLER/Alarms/Alarms/raw/formatted_/formated.csv

# %%
df_alarms = obj.convertRecords2Alarms(temp_df)
# Out:
# Test:48TIC2026
# end
# [1]Source:48TIC2026, Conditions:['VEL+' 'VEL-'], Total Alarms:585895
# Test:47TI931A
# end
# [2]Source:47TI931A, Conditions:['IOP'], Total Alarms:220452
# Test:19LI105A
# end
# [3]Source:19LI105A, Conditions:['LO' 'LL' 'VEL+' 'VEL-'], Total Alarms:51445
# Test:48PAL007-ANN
# end
# [4]Source:48PAL007-ANN, Conditions:['ALM'], Total Alarms:23704
# Test:47LAHH2003-1X-AN
# end
# [5]Source:47LAHH2003-1X-AN, Conditions:['ALM'], Total Alarms:19654
# Test:47LI2001
# end
# [6]Source:47LI2001, Conditions:['HTRP'], Total Alarms:18134
# Test:47TI003B
# end
# [7]Source:47TI003B, Conditions:['LLL' 'LTRP'], Total Alarms:6094
# Test:47PDI1746
# end
# [8]Source:47PDI1746, Conditions:['IOP'], Total Alarms:4692
# Test:47FLI-032
# end
# [9]Source:47FLI-032, Conditions:['IOP' 'CNF'], Total Alarms:3902
# Test:47TI1713
# end
# [10]Source:47TI1713, Conditions:['IOP' 'IOP-'], Total Alarms:3895
# Test:47USI802
# end
# [11]Source:47USI802, Conditions:['LLL' 'LTRP'], Total Alarms:2873
# Test:19XL101-ANN
# end
# [12]Source:19XL101-ANN, Conditions:['ALM'], Total Alarms:2763
# Test:19G402-ANN
# end
# [13]Source:19G402-ANN, Conditions:['ALM'], Total Alarms:2763
# Test:47TI002C
# end
# [14]Source:47TI002C, Conditions:['LLL'], Total Alarms:2695
# Test:47AIT2011
# end
# [15]Source:47AIT2011, Conditions:['LL' 'LO' 'HH' 'HI' 'IOP-'], Total Alarms:1866
# Test:47TI003A
# end
# [16]Source:47TI003A, Conditions:['LLL' 'LTRP'], Total Alarms:1586
# Test:SIO-18XA001
# end
# [17]Source:SIO-18XA001, Conditions:['ANS-'], Total Alarms:1578
# Test:47FI1575
# end
# [18]Source:47FI1575, Conditions:['IOP'], Total Alarms:1365
# Test:47PIC1755
# end
# [19]Source:47PIC1755, Conditions:['IOP'], Total Alarms:1169
# Test:48PI2025
# end
# [20]Source:48PI2025, Conditions:['IOP' 'HH' 'HI' 'IOP-'], Total Alarms:1079
# Test:48XL001-ANN
# end
# [21]Source:48XL001-ANN, Conditions:['ALM'], Total Alarms:860
# Test:47AIT2013
# end
# [22]Source:47AIT2013, Conditions:['LO' 'IOP' 'IOP-'], Total Alarms:761
# Test:47TAL003AB-ANN
# end
# [23]Source:47TAL003AB-ANN, Conditions:['ALM'], Total Alarms:527
# Test:47FI1568
# end
# [24]Source:47FI1568, Conditions:['IOP'], Total Alarms:487
# Test:47FLI-039
# end
# [25]Source:47FLI-039, Conditions:['IOP' 'CNF'], Total Alarms:414
# Test:47FI043
# end
# [26]Source:47FI043, Conditions:['HI'], Total Alarms:403
# Test:47TI1512A
# end
# [27]Source:47TI1512A, Conditions:['HHH'], Total Alarms:290
# Test:47TI1512B
# end
# [28]Source:47TI1512B, Conditions:['HHH'], Total Alarms:279
# Test:48PAL013-ANN
# end
# [29]Source:48PAL013-ANN, Conditions:['ALM'], Total Alarms:268
# Test:47TI1512ABC
# end
# [30]Source:47TI1512ABC, Conditions:['HHH'], Total Alarms:267
# Test:48TIC034
# end
# [31]Source:48TIC034, Conditions:['LO' 'LL' 'HH' 'HI' 'DV-' 'DV+'], Total Alarms:264
# Test:47TI1512C
# end
# [32]Source:47TI1512C, Conditions:['HHH'], Total Alarms:252
# Test:47TIC3520
# end
# [33]Source:47TIC3520, Conditions:['LO' 'DV+' 'HI' 'HH' 'DV-'], Total Alarms:237
# Test:48XL002-ANN
# end
# [34]Source:48XL002-ANN, Conditions:['ALM'], Total Alarms:206
# Test:47PIC2033A
# end
# [35]Source:47PIC2033A, Conditions:['HI' 'HH'], Total Alarms:189
# Test:47FIC1543
# end
# [36]Source:47FIC1543, Conditions:['VEL+' 'VEL-' 'HI' 'HH'], Total Alarms:143
# Test:47LI024
# end
# [37]Source:47LI024, Conditions:['IOP' 'HI' 'HH'], Total Alarms:142
# Test:47PIC027-ANN
# end
# [38]Source:47PIC027-ANN, Conditions:['ALM'], Total Alarms:140
# Test:47PIC1505
# end
# [39]Source:47PIC1505, Conditions:['LO' 'LL' 'HI'], Total Alarms:138
# Test:47LI003
# end
# [40]Source:47LI003, Conditions:['HTRP' 'LTRP'], Total Alarms:127
# Test:47PDIC1759
# end
# [41]Source:47PDIC1759, Conditions:['IOP'], Total Alarms:122
# Test:47PIC3522
# end
# [42]Source:47PIC3522, Conditions:['LL' 'LO' 'HI' 'DV+' 'HH' 'DV-'], Total Alarms:105
# Test:47AI2003
# end
# [43]Source:47AI2003, Conditions:['HI' 'IOP' 'IOP-'], Total Alarms:104
# Test:48TI004
# end
# [44]Source:48TI004, Conditions:['IOP' 'LL' 'LO' 'IOP-' 'HI' 'HH'], Total Alarms:99
# Test:47FI1005
# end
# [45]Source:47FI1005, Conditions:['IOP' 'LO'], Total Alarms:99
# Test:48AIC001
# end
# [46]Source:48AIC001, Conditions:['HI' 'LO' 'IOP-' 'DV+' 'DV-'], Total Alarms:92
# Test:47PI1734
# end
# [47]Source:47PI1734, Conditions:['IOP' 'IOP-' 'HI' 'HH' 'LO' 'LL'], Total Alarms:81
# Test:47TXI1594
# end
# [48]Source:47TXI1594, Conditions:['HI'], Total Alarms:84
# Test:47LIC3408
# end
# [49]Source:47LIC3408, Conditions:['HI' 'HH' 'LL' 'LO'], Total Alarms:83
# Test:47LIC1506
# end
# [50]Source:47LIC1506, Conditions:['HI' 'LO'], Total Alarms:80
# Test:47FIC1522A
# end
# [51]Source:47FIC1522A, Conditions:['DV-' 'DV+'], Total Alarms:78
# Test:48LI015
# end
# [52]Source:48LI015, Conditions:['LO' 'LL'], Total Alarms:75
# Test:47HCI-003
# end
# [53]Source:47HCI-003, Conditions:['CNF' 'IOP'], Total Alarms:76
# Test:47FI1631
# end
# [54]Source:47FI1631, Conditions:['HI'], Total Alarms:76
# Test:48FIX2040
# end
# [55]Source:48FIX2040, Conditions:['IOP-'], Total Alarms:74
# Test:48TIC2027
# end
# [56]Source:48TIC2027, Conditions:['IOP-'], Total Alarms:74
# Test:47PI1512
# end
# [57]Source:47PI1512, Conditions:['LO' 'LL' 'HI' 'HH'], Total Alarms:70
# Test:01AAH5-6-ANN
# end
# [58]Source:01AAH5-6-ANN, Conditions:['ALM'], Total Alarms:68
# Test:48XL009-ANN
# end
# [59]Source:48XL009-ANN, Conditions:['ALM'], Total Alarms:64
# Test:47TI1769
# end
# [60]Source:47TI1769, Conditions:['HI' 'HH'], Total Alarms:63
# Test:48LI013
# end
# [61]Source:48LI013, Conditions:['LO' 'HI' 'LL'], Total Alarms:62
# Test:47XL015-ANN
# end
# [62]Source:47XL015-ANN, Conditions:['ALM'], Total Alarms:63
# Test:47XL016-ANN
# end
# [63]Source:47XL016-ANN, Conditions:['ALM'], Total Alarms:63
# Test:48LI011
# end
# [64]Source:48LI011, Conditions:['LO' 'HI' 'LL'], Total Alarms:62
# Test:48XL010-ANN
# end
# [65]Source:48XL010-ANN, Conditions:['ALM'], Total Alarms:59
# Test:47PIC2028
# end
# [66]Source:47PIC2028, Conditions:['HI'], Total Alarms:58
# Test:47_AMPSB_PMCC1L
# end
# [67]Source:47_AMPSB_PMCC1L, Conditions:['HI'], Total Alarms:55
# Test:47LIC005
# end
# [68]Source:47LIC005, Conditions:['HI' 'LL' 'LO' 'IOP-'], Total Alarms:51
# Test:47PDI003
# end
# [69]Source:47PDI003, Conditions:['HTRP'], Total Alarms:53
# Test:47LIC1501
# end
# [70]Source:47LIC1501, Conditions:['HI' 'LO'], Total Alarms:52
# Test:47FIC035
# end
# [71]Source:47FIC035, Conditions:['DV+' 'DV-'], Total Alarms:49
# Test:48LIC009
# end
# [72]Source:48LIC009, Conditions:['HI' 'LO'], Total Alarms:42
# Test:47LIC1518
# end
# [73]Source:47LIC1518, Conditions:['HI' 'HH'], Total Alarms:40
# Test:47LIC009
# end
# [74]Source:47LIC009, Conditions:['LO'], Total Alarms:39
# Test:19LIC104
# end
# [75]Source:19LIC104, Conditions:['LO' 'LL' 'HI'], Total Alarms:36
# Test:47LI850C
# end
# [76]Source:47LI850C, Conditions:['LLL'], Total Alarms:38
# Test:47CEMS-SO2N
# end
# [77]Source:47CEMS-SO2N, Conditions:['LO' 'LL' 'HH' 'HI'], Total Alarms:37
# Test:47TI1506
# end
# [78]Source:47TI1506, Conditions:['LO' 'HI'], Total Alarms:34
# Test:47LIC1522
# end
# [79]Source:47LIC1522, Conditions:['LO' 'IOP-' 'HH' 'HI'], Total Alarms:36
# Test:48XL006-ANN
# end
# [80]Source:48XL006-ANN, Conditions:['ALM'], Total Alarms:34
# Test:47LI606A
# end
# [81]Source:47LI606A, Conditions:['HTRP'], Total Alarms:34
# Test:19LIC103
# end
# [82]Source:19LIC103, Conditions:['LL' 'LO'], Total Alarms:35
# Test:47TI2112A
# end
# [83]Source:47TI2112A, Conditions:['LLL'], Total Alarms:33
# Test:48TI035B
# end
# [84]Source:48TI035B, Conditions:['HHH'], Total Alarms:32
# Test:01XA016-ANN
# end
# [85]Source:01XA016-ANN, Conditions:['ALM'], Total Alarms:32
# Test:47_AMPSC_PMCC1L
# end
# [86]Source:47_AMPSC_PMCC1L, Conditions:['HI'], Total Alarms:28
# Test:48AAH010-ANN
# end
# [87]Source:48AAH010-ANN, Conditions:['ALM'], Total Alarms:27
# Test:48LI010
# end
# [88]Source:48LI010, Conditions:['HI' 'LO'], Total Alarms:27
# Test:47TI2112B
# end
# [89]Source:47TI2112B, Conditions:['LLL'], Total Alarms:25
# Test:01AAH2-3-ANN
# end
# [90]Source:01AAH2-3-ANN, Conditions:['ALM'], Total Alarms:26
# Test:47LIC3101
# end
# [91]Source:47LIC3101, Conditions:['HI' 'HH'], Total Alarms:26
# Test:47_AMPSA_PMCC1L
# end
# [92]Source:47_AMPSA_PMCC1L, Conditions:['HI'], Total Alarms:23
# Test:48XL005-ANN
# end
# [93]Source:48XL005-ANN, Conditions:['ALM'], Total Alarms:22
# Test:48XL008-ANN
# end
# [94]Source:48XL008-ANN, Conditions:['ALM'], Total Alarms:20
# Test:47LIC1555
# end
# [95]Source:47LIC1555, Conditions:['HI' 'LO' 'LL'], Total Alarms:20
# Test:47FI3005
# end
# [96]Source:47FI3005, Conditions:['IOP'], Total Alarms:19
# Test:47FIC1520
# end
# [97]Source:47FIC1520, Conditions:['HI' 'DV+' 'LO' 'DV-'], Total Alarms:20
# Test:19LIC102
# end
# [98]Source:19LIC102, Conditions:['HI'], Total Alarms:19
# Test:48LIC002
# end
# [99]Source:48LIC002, Conditions:['HI' 'HH'], Total Alarms:20
# Test:48TIC2040
# end
# [100]Source:48TIC2040, Conditions:['VEL+' 'VEL-' 'IOP'], Total Alarms:18
# Test:47TI416
# end
# [101]Source:47TI416, Conditions:['HI' 'LO'], Total Alarms:18
# Test:47AIT2014
# end
# [102]Source:47AIT2014, Conditions:['HI' 'IOP-' 'HH'], Total Alarms:18
# Test:47FIC020
# end
# [103]Source:47FIC020, Conditions:['HI'], Total Alarms:17
# Test:47LIC1513
# end
# [104]Source:47LIC1513, Conditions:['LO' 'LL' 'HI'], Total Alarms:17
# Test:47PIC3522-ANN
# end
# [105]Source:47PIC3522-ANN, Conditions:['ALM'], Total Alarms:17
# Test:47TI1509
# end
# [106]Source:47TI1509, Conditions:['HI'], Total Alarms:16
# Test:48FFIC019
# end
# [107]Source:48FFIC019, Conditions:['HI' 'DV+'], Total Alarms:15
# Test:47TI2111A
# end
# [108]Source:47TI2111A, Conditions:['LLL'], Total Alarms:14
# Test:47LIC015
# end
# [109]Source:47LIC015, Conditions:['HI' 'LL' 'LO'], Total Alarms:14
# Test:47TI1533
# end
# [110]Source:47TI1533, Conditions:['HI' 'HH' 'LO' 'LL'], Total Alarms:13
# Test:47HSD-008H-ANN
# end
# [111]Source:47HSD-008H-ANN, Conditions:['ALM'], Total Alarms:14
# Test:47TIC2056_D
# end
# [112]Source:47TIC2056_D, Conditions:['DV+' 'DV-' 'LO'], Total Alarms:14
# Test:48FFIC2002
# end
# [113]Source:48FFIC2002, Conditions:['HI' 'VEL+' 'VEL-'], Total Alarms:12
# Test:47PIC2038
# end
# [114]Source:47PIC2038, Conditions:['HI' 'HH'], Total Alarms:10
# Test:47FD-032H-ANN
# end
# [115]Source:47FD-032H-ANN, Conditions:['ALM'], Total Alarms:12
# Test:47LIC3409
# end
# [116]Source:47LIC3409, Conditions:['DV+' 'HI'], Total Alarms:12
# Test:47TIC2050_N_D
# end
# [117]Source:47TIC2050_N_D, Conditions:['DV-' 'DV+'], Total Alarms:12
# Test:47FD-032HH-ANN
# end
# [118]Source:47FD-032HH-ANN, Conditions:['ALM'], Total Alarms:12
# Test:47TI618
# end
# [119]Source:47TI618, Conditions:['HI'], Total Alarms:10
# Test:47TAH418A-ANN
# end
# [120]Source:47TAH418A-ANN, Conditions:['ALM'], Total Alarms:11
# Test:47G12-A
# end
# [121]Source:47G12-A, Conditions:['ANS-' 'ANS+'], Total Alarms:11
# Test:47TI2058A
# end
# [122]Source:47TI2058A, Conditions:['HI'], Total Alarms:11
# Test:01XA033-ANN
# end
# [123]Source:01XA033-ANN, Conditions:['ALM'], Total Alarms:11
# Test:01XA022-ANN
# end
# [124]Source:01XA022-ANN, Conditions:['ALM'], Total Alarms:11
# Test:47PIC2027
# end
# [125]Source:47PIC2027, Conditions:['DV-' 'LL' 'LO'], Total Alarms:10
# Test:47FI1017A
# end
# [126]Source:47FI1017A, Conditions:['LL' 'LO'], Total Alarms:10
# Test:47FI3307
# end
# [127]Source:47FI3307, Conditions:['LO'], Total Alarms:10
# Test:47TI1521
# end
# [128]Source:47TI1521, Conditions:['LO' 'HI'], Total Alarms:10
# Test:19TI104
# end
# [129]Source:19TI104, Conditions:['LO'], Total Alarms:9
# Test:48AAH007-ANN
# end
# [130]Source:48AAH007-ANN, Conditions:['ALM'], Total Alarms:10
# Test:47AAH009-ANN
# end
# [131]Source:47AAH009-ANN, Conditions:['ALM'], Total Alarms:10
# Test:47XL1001-ANN
# end
# [132]Source:47XL1001-ANN, Conditions:['ALM'], Total Alarms:9
# Test:47EM304D-ANN
# end
# [133]Source:47EM304D-ANN, Conditions:['ALM'], Total Alarms:8
# Test:47HSD-008HH-ANN
# end
# [134]Source:47HSD-008HH-ANN, Conditions:['ALM'], Total Alarms:9
# Test:47TI870A
# end
# [135]Source:47TI870A, Conditions:['HHH' 'HTRP'], Total Alarms:9
# Test:47FIC1524
# end
# [136]Source:47FIC1524, Conditions:['IOP'], Total Alarms:9
# Test:47FIC1524_CALX
# end
# [137]Source:47FIC1524_CALX, Conditions:['IOP'], Total Alarms:9
# Test:47TI1705
# end
# [138]Source:47TI1705, Conditions:['LO' 'HI'], Total Alarms:8
# Test:48TIC038
# end
# [139]Source:48TIC038, Conditions:['HI'], Total Alarms:8
# Test:47PI1003
# end
# [140]Source:47PI1003, Conditions:['HI' 'LO' 'LL'], Total Alarms:8
# Test:47LIC1510
# end
# [141]Source:47LIC1510, Conditions:['LO' 'LL'], Total Alarms:8
# Test:47TI3519
# end
# [142]Source:47TI3519, Conditions:['LO' 'HI'], Total Alarms:8
# Test:48TI035A
# end
# [143]Source:48TI035A, Conditions:['HHH'], Total Alarms:8
# Test:47TIC2050_N
# end
# [144]Source:47TIC2050_N, Conditions:['DV+' 'MLO' 'MHI' 'DV-'], Total Alarms:7
# Test:47PI951
# end
# [145]Source:47PI951, Conditions:['LO' 'LL'], Total Alarms:7
# Test:47AI2013
# end
# [146]Source:47AI2013, Conditions:['IOP-' 'IOP'], Total Alarms:7
# Test:47PI2034ABC
# end
# [147]Source:47PI2034ABC, Conditions:['LLL' 'LTRP'], Total Alarms:6
# Test:47TIC1511
# end
# [148]Source:47TIC1511, Conditions:['HI' 'LO'], Total Alarms:5
# Test:47PIC027
# end
# [149]Source:47PIC027, Conditions:['LO' 'HI' 'HH'], Total Alarms:7
# Test:47TIC1535
# end
# [150]Source:47TIC1535, Conditions:['HH' 'HI' 'LO' 'LL'], Total Alarms:7
# Test:F201-CEM-CAL3
# end
# [151]Source:F201-CEM-CAL3, Conditions:['IOP' 'IOP-'], Total Alarms:7
# Test:19PI119A
# end
# [152]Source:19PI119A, Conditions:['LO' 'LL'], Total Alarms:5
# Test:47APC_F21_OFF-AN
# end
# [153]Source:47APC_F21_OFF-AN, Conditions:['ALM'], Total Alarms:6
# Test:19G402
# end
# [154]Source:19G402, Conditions:['ANS+'], Total Alarms:6
# Test:47PDI3104
# end
# [155]Source:47PDI3104, Conditions:['HH' 'HI'], Total Alarms:6
# Test:47TI2072
# end
# [156]Source:47TI2072, Conditions:['HI'], Total Alarms:6
# Test:47HCI-077
# end
# [157]Source:47HCI-077, Conditions:['CNF' 'IOP'], Total Alarms:6
# Test:47TIC3417
# end
# [158]Source:47TIC3417, Conditions:['HI'], Total Alarms:6
# Test:47LIC1511
# end
# [159]Source:47LIC1511, Conditions:['LO' 'HI'], Total Alarms:6
# Test:47LIC002
# end
# [160]Source:47LIC002, Conditions:['HI' 'LO'], Total Alarms:6
# Test:48FI020
# end
# [161]Source:48FI020, Conditions:['HI' 'HH'], Total Alarms:5
# Test:47TI414G
# end
# [162]Source:47TI414G, Conditions:['LO' 'LL'], Total Alarms:6
# Test:47FI046
# end
# [163]Source:47FI046, Conditions:['HI' 'IOP'], Total Alarms:6
# Test:47LIC1001
# end
# [164]Source:47LIC1001, Conditions:['HI'], Total Alarms:6
# Test:47LIC3103
# end
# [165]Source:47LIC3103, Conditions:['LO' 'LL' 'HI'], Total Alarms:6
# Test:19LAH101-ANN
# end
# [166]Source:19LAH101-ANN, Conditions:['ALM'], Total Alarms:6
# Test:47TI2057B
# end
# [167]Source:47TI2057B, Conditions:['HI' 'HH'], Total Alarms:5
# Test:47G122-ANN
# end
# [168]Source:47G122-ANN, Conditions:['ALM'], Total Alarms:5
# Test:47LIC1520
# end
# [169]Source:47LIC1520, Conditions:['LO' 'HI'], Total Alarms:6
# Test:47BA001P-ANN
# end
# [170]Source:47BA001P-ANN, Conditions:['ALM'], Total Alarms:5
# Test:47TI1724
# end
# [171]Source:47TI1724, Conditions:['LO'], Total Alarms:6
# Test:47APC_F21_ON-ANN
# end
# [172]Source:47APC_F21_ON-ANN, Conditions:['ALM'], Total Alarms:6
# Test:18LI702
# end
# [173]Source:18LI702, Conditions:['HH' 'HI' 'LO' 'LL'], Total Alarms:6
# Test:47TI2112ABC
# end
# [174]Source:47TI2112ABC, Conditions:['HTRP' 'HHH' 'LLL'], Total Alarms:5
# Test:47FIC012
# end
# [175]Source:47FIC012, Conditions:['HI' 'HH'], Total Alarms:5
# Test:47TI1540
# end
# [176]Source:47TI1540, Conditions:['HI'], Total Alarms:5
# Test:47PIC2023
# end
# [177]Source:47PIC2023, Conditions:['LO' 'HI' 'LL'], Total Alarms:3
# Test:47TI1507
# end
# [178]Source:47TI1507, Conditions:['HI' 'HH'], Total Alarms:5
# Test:47TI414Q
# end
# [179]Source:47TI414Q, Conditions:['LO' 'LL'], Total Alarms:5
# Test:47XL1525B-ANN
# end
# [180]Source:47XL1525B-ANN, Conditions:['ALM'], Total Alarms:4
# Test:47FIC2036_N
# end
# [181]Source:47FIC2036_N, Conditions:['DV-' 'MHI' 'MLO' 'DV+'], Total Alarms:5
# Test:47AAH302-ANN
# end
# [182]Source:47AAH302-ANN, Conditions:['ALM'], Total Alarms:5
# Test:47TI2058B
# end
# [183]Source:47TI2058B, Conditions:['HI'], Total Alarms:5
# Test:47FIC1523
# end
# [184]Source:47FIC1523, Conditions:['DV+' 'DV-'], Total Alarms:5
# Test:47PIC2033B
# end
# [185]Source:47PIC2033B, Conditions:['VEL+' 'HH' 'HI'], Total Alarms:5
# Test:47PI1710
# end
# [186]Source:47PI1710, Conditions:['HI'], Total Alarms:4
# Test:47AIT2012
# end
# [187]Source:47AIT2012, Conditions:['IOP-'], Total Alarms:4
# Test:47FD-036H-ANN
# end
# [188]Source:47FD-036H-ANN, Conditions:['ALM'], Total Alarms:4
# Test:47TIC2056_N
# end
# [189]Source:47TIC2056_N, Conditions:['MLO' 'MHI' 'LO'], Total Alarms:4
# Test:47FIC1512
# end
# [190]Source:47FIC1512, Conditions:['LO' 'LL' 'DV-' 'DV+'], Total Alarms:4
# Test:19FI101
# end
# [191]Source:19FI101, Conditions:['HI' 'HH'], Total Alarms:4
# Test:47TI414B
# end
# [192]Source:47TI414B, Conditions:['LL' 'LO'], Total Alarms:4
# Test:47LI011
# end
# [193]Source:47LI011, Conditions:['HI'], Total Alarms:4
# Test:47TI3531
# end
# [194]Source:47TI3531, Conditions:['LO' 'HH'], Total Alarms:4
# Test:47FIC1632
# end
# [195]Source:47FIC1632, Conditions:['MLO'], Total Alarms:4
# Test:47HII-017
# end
# [196]Source:47HII-017, Conditions:['IOP' 'CNF'], Total Alarms:4
# Test:47XL1526B-ANN
# end
# [197]Source:47XL1526B-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47TI2111
# end
# [198]Source:47TI2111, Conditions:['IOP'], Total Alarms:4
# Test:48HSI-001
# end
# [199]Source:48HSI-001, Conditions:['CNF' 'IOP'], Total Alarms:4
# Test:47FD-036HH-ANN
# end
# [200]Source:47FD-036HH-ANN, Conditions:['ALM'], Total Alarms:4
# Test:47AI2012
# end
# [201]Source:47AI2012, Conditions:['IOP-'], Total Alarms:4
# Test:F201-CEM-CAL2
# end
# [202]Source:F201-CEM-CAL2, Conditions:['IOP-'], Total Alarms:4
# Test:47FLI-037
# end
# [203]Source:47FLI-037, Conditions:['IOP' 'CNF'], Total Alarms:4
# Test:47PIC1760
# end
# [204]Source:47PIC1760, Conditions:['LO' 'LL'], Total Alarms:4
# Test:47APC_F21_WD-ANN
# end
# [205]Source:47APC_F21_WD-ANN, Conditions:['ALM'], Total Alarms:4
# Test:47LIC1509
# end
# [206]Source:47LIC1509, Conditions:['LO' 'LL'], Total Alarms:4
# Test:47TI2057A
# end
# [207]Source:47TI2057A, Conditions:['HI' 'HH'], Total Alarms:4
# Test:47AAH303-ANN
# end
# [208]Source:47AAH303-ANN, Conditions:['ALM'], Total Alarms:4
# Test:47LIC1515
# end
# [209]Source:47LIC1515, Conditions:['HI' 'LO'], Total Alarms:4
# Test:47FI032
# end
# [210]Source:47FI032, Conditions:['LO'], Total Alarms:4
# Test:47FIC1527
# end
# [211]Source:47FIC1527, Conditions:['HI'], Total Alarms:4
# Test:48FI013
# end
# [212]Source:48FI013, Conditions:['HI' 'HH'], Total Alarms:4
# Test:47TI929F
# end
# [213]Source:47TI929F, Conditions:['HI' 'LO'], Total Alarms:2
# Test:47PI950
# end
# [214]Source:47PI950, Conditions:['LO'], Total Alarms:3
# Test:47TIC1501
# end
# [215]Source:47TIC1501, Conditions:['HI' 'LO' 'DV-'], Total Alarms:3
# Test:19ZAL119A-ANN
# end
# [216]Source:19ZAL119A-ANN, Conditions:['ALM'], Total Alarms:3
# Test:47AI005
# end
# [217]Source:47AI005, Conditions:['HI'], Total Alarms:2
# Test:48AI002
# end
# [218]Source:48AI002, Conditions:['IOP-' 'IOP'], Total Alarms:3
# Test:48AI003
# end
# [219]Source:48AI003, Conditions:['IOP-' 'IOP'], Total Alarms:3
# Test:47TIC413
# end
# [220]Source:47TIC413, Conditions:['LO' 'LL'], Total Alarms:3
# Test:19ZAH119A-ANN
# end
# [221]Source:19ZAH119A-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47TI1529
# end
# [222]Source:47TI1529, Conditions:['HI' 'LO'], Total Alarms:3
# Test:47FIC2036
# end
# [223]Source:47FIC2036, Conditions:['MHI' 'MLO'], Total Alarms:3
# Test:47PI2065
# end
# [224]Source:47PI2065, Conditions:['LO' 'LL'], Total Alarms:3
# Test:01XA017-ANN
# end
# [225]Source:01XA017-ANN, Conditions:['ALM'], Total Alarms:3
# Test:47HCD-046H-ANN
# end
# [226]Source:47HCD-046H-ANN, Conditions:['ALM'], Total Alarms:3
# Test:47XL3602-ANN
# end
# [227]Source:47XL3602-ANN, Conditions:['ALM'], Total Alarms:2
# Test:19AAH101-ANN
# end
# [228]Source:19AAH101-ANN, Conditions:['ALM'], Total Alarms:3
# Test:47FI047
# end
# [229]Source:47FI047, Conditions:['IOP'], Total Alarms:3
# Test:47XA1503-ANN
# end
# [230]Source:47XA1503-ANN, Conditions:['ALM'], Total Alarms:3
# Test:47TI414H
# end
# [231]Source:47TI414H, Conditions:['LO'], Total Alarms:3
# Test:47TI611
# end
# [232]Source:47TI611, Conditions:['LL' 'LO' 'HI'], Total Alarms:3
# Test:47FIC1529
# end
# [233]Source:47FIC1529, Conditions:['LO' 'LL' 'HI'], Total Alarms:3
# Test:48FIC007
# end
# [234]Source:48FIC007, Conditions:['VEL+' 'VEL-'], Total Alarms:3
# Test:47FIC1513
# end
# [235]Source:47FIC1513, Conditions:['DV-' 'DV+' 'HI'], Total Alarms:3
# Test:47LIC004
# end
# [236]Source:47LIC004, Conditions:['HH'], Total Alarms:3
# Test:47LIC1507
# end
# [237]Source:47LIC1507, Conditions:['LO'], Total Alarms:3
# Test:47TI3416
# end
# [238]Source:47TI3416, Conditions:['HI'], Total Alarms:2
# Test:47YS_ORAN
# end
# [239]Source:47YS_ORAN, Conditions:['IOP'], Total Alarms:3
# Test:47XL017C-ANN
# end
# [240]Source:47XL017C-ANN, Conditions:['ALM'], Total Alarms:1
# Test:19FI108A
# end
# [241]Source:19FI108A, Conditions:['LL' 'LO' 'HI'], Total Alarms:2
# Test:47PIC2064
# end
# [242]Source:47PIC2064, Conditions:['LO'], Total Alarms:2
# Test:47TIC2078
# end
# [243]Source:47TIC2078, Conditions:['DV-'], Total Alarms:2
# Test:47XL3508-ANN
# end
# [244]Source:47XL3508-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48FI2003A
# end
# [245]Source:48FI2003A, Conditions:['LLL' 'LTRP'], Total Alarms:2
# Test:48HSD-002H-ANN
# end
# [246]Source:48HSD-002H-ANN, Conditions:['ALM'], Total Alarms:2
# Test:48HSD-002HH-ANN
# end
# [247]Source:48HSD-002HH-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47FLI-014
# end
# [248]Source:47FLI-014, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:47FLI-068
# end
# [249]Source:47FLI-068, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:47CEMS-NOXN
# end
# [250]Source:47CEMS-NOXN, Conditions:['HI' 'HH'], Total Alarms:2
# Test:48HSD-001HH-ANN
# end
# [251]Source:48HSD-001HH-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47TIC1551
# end
# [252]Source:47TIC1551, Conditions:['HI'], Total Alarms:2
# Test:48AAH008-ANN
# end
# [253]Source:48AAH008-ANN, Conditions:['ALM'], Total Alarms:2
# Test:48HSI-002
# end
# [254]Source:48HSI-002, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47FIC1507
# end
# [255]Source:47FIC1507, Conditions:['HI'], Total Alarms:2
# Test:47FLI-076
# end
# [256]Source:47FLI-076, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:47AI002
# end
# [257]Source:47AI002, Conditions:['IOP-'], Total Alarms:2
# Test:47PDIC1502
# end
# [258]Source:47PDIC1502, Conditions:['HI' 'LO'], Total Alarms:2
# Test:01XA018-ANN
# end
# [259]Source:01XA018-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47XL1552-ANN
# end
# [260]Source:47XL1552-ANN, Conditions:['ALM'], Total Alarms:2
# Test:01XA023-ANN
# end
# [261]Source:01XA023-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47PI2002
# end
# [262]Source:47PI2002, Conditions:['LO'], Total Alarms:1
# Test:47PIC1507
# end
# [263]Source:47PIC1507, Conditions:['MLO'], Total Alarms:2
# Test:47HSI-008
# end
# [264]Source:47HSI-008, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47FIC2002
# end
# [265]Source:47FIC2002, Conditions:['LO'], Total Alarms:2
# Test:01XA039-ANN
# end
# [266]Source:01XA039-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47FLI-035
# end
# [267]Source:47FLI-035, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:47HCD-043H-ANN
# end
# [268]Source:47HCD-043H-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47XL1551-ANN
# end
# [269]Source:47XL1551-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-001H-ANN
# end
# [270]Source:47HCD-001H-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47PI626
# end
# [271]Source:47PI626, Conditions:['LO'], Total Alarms:2
# Test:47FLI-069
# end
# [272]Source:47FLI-069, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:47LIC3404
# end
# [273]Source:47LIC3404, Conditions:['LO'], Total Alarms:2
# Test:47TI926I
# end
# [274]Source:47TI926I, Conditions:['HI'], Total Alarms:2
# Test:47HII-018
# end
# [275]Source:47HII-018, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47FIC2017
# end
# [276]Source:47FIC2017, Conditions:['HI'], Total Alarms:2
# Test:47HCI-079
# end
# [277]Source:47HCI-079, Conditions:['CNF' 'IOP'], Total Alarms:2
# Test:01XA034-ANN
# end
# [278]Source:01XA034-ANN, Conditions:['ALM'], Total Alarms:2
# Test:48HSD-001H-ANN
# end
# [279]Source:48HSD-001H-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47HII-020
# end
# [280]Source:47HII-020, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47TI3102
# end
# [281]Source:47TI3102, Conditions:['HI'], Total Alarms:2
# Test:01XA030-ANN
# end
# [282]Source:01XA030-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47TI1508
# end
# [283]Source:47TI1508, Conditions:['HI'], Total Alarms:2
# Test:01XA024-ANN
# end
# [284]Source:01XA024-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47PI2067
# end
# [285]Source:47PI2067, Conditions:['LO'], Total Alarms:2
# Test:47HCD-046HH-ANN
# end
# [286]Source:47HCD-046HH-ANN, Conditions:['ALM'], Total Alarms:2
# Test:47AI2011
# end
# [287]Source:47AI2011, Conditions:['IOP-'], Total Alarms:2
# Test:F201-CEM-CAL1
# end
# [288]Source:F201-CEM-CAL1, Conditions:['IOP-'], Total Alarms:2
# Test:47PI706
# end
# [289]Source:47PI706, Conditions:['LLL' 'LTRP'], Total Alarms:2
# Test:47HII-016
# end
# [290]Source:47HII-016, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47HII-019
# end
# [291]Source:47HII-019, Conditions:['IOP' 'CNF'], Total Alarms:2
# Test:47FIC2032_N
# end
# [292]Source:47FIC2032_N, Conditions:['MHI'], Total Alarms:1
# Test:47XL017G-ANN
# end
# [293]Source:47XL017G-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI010
# end
# [294]Source:47PI010, Conditions:['HI'], Total Alarms:1
# Test:01XL029-ANN
# end
# [295]Source:01XL029-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL026A-ANN
# end
# [296]Source:47XL026A-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LI951
# end
# [297]Source:47LI951, Conditions:['LL' 'LO'], Total Alarms:1
# Test:47XL026B-ANN
# end
# [298]Source:47XL026B-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LIC2001
# end
# [299]Source:47LIC2001, Conditions:['HI'], Total Alarms:1
# Test:47G17A-ANN
# end
# [300]Source:47G17A-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-010HH-ANN
# end
# [301]Source:47FD-010HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-003H-ANN
# end
# [302]Source:47HCD-003H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TAIL_DUTY2
# end
# [303]Source:47TAIL_DUTY2, Conditions:['IOP'], Total Alarms:1
# Test:47CEMS-CON
# end
# [304]Source:47CEMS-CON, Conditions:['HI' 'HH'], Total Alarms:0
# Test:47AI2002
# end
# [305]Source:47AI2002, Conditions:['IOP-'], Total Alarms:1
# Test:47AAH005-ANN
# end
# [306]Source:47AAH005-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-016H-ANN
# end
# [307]Source:47HID-016H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47UA2500-ANN
# end
# [308]Source:47UA2500-ANN, Conditions:['ALM'], Total Alarms:1
# Test:01XA042-ANN
# end
# [309]Source:01XA042-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-026H-ANN
# end
# [310]Source:47HCD-026H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-063HH-ANN
# end
# [311]Source:47HCD-063HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-058H-ANN
# end
# [312]Source:47HSD-058H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-020HH-ANN
# end
# [313]Source:47HID-020HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-048H-ANN
# end
# [314]Source:47HCD-048H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-027H-ANN
# end
# [315]Source:47HCD-027H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-050HH-ANN
# end
# [316]Source:47HSD-050HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AI2001_D1
# end
# [317]Source:47AI2001_D1, Conditions:['IOP-'], Total Alarms:1
# Test:47FD-072HH-ANN
# end
# [318]Source:47FD-072HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-048HH-ANN
# end
# [319]Source:47HCD-048HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AH011-ANN
# end
# [320]Source:47AH011-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47_AMPSB_PMCC2R
# end
# [321]Source:47_AMPSB_PMCC2R, Conditions:['IOP'], Total Alarms:1
# Test:47HSD-025HH-ANN
# end
# [322]Source:47HSD-025HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH005-ANN
# end
# [323]Source:48AAH005-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI2029A
# end
# [324]Source:47PI2029A, Conditions:['LLL'], Total Alarms:1
# Test:48AAH2005-ANN
# end
# [325]Source:48AAH2005-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-064H-ANN
# end
# [326]Source:47HCD-064H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI2111ABC
# end
# [327]Source:47TI2111ABC, Conditions:['LLL'], Total Alarms:0
# Test:47F-101
# end
# [328]Source:47F-101, Conditions:['IOP'], Total Alarms:1
# Test:47AI2001_DLAY
# end
# [329]Source:47AI2001_DLAY, Conditions:['IOP'], Total Alarms:1
# Test:47HCD-047H-ANN
# end
# [330]Source:47HCD-047H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-012H-ANN
# end
# [331]Source:47HCD-012H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH015-ANN
# end
# [332]Source:47AAH015-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AI2014
# end
# [333]Source:47AI2014, Conditions:['IOP-'], Total Alarms:1
# Test:47FD-021HH-ANN
# end
# [334]Source:47FD-021HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LI608
# end
# [335]Source:47LI608, Conditions:['LTRP' 'LLL'], Total Alarms:0
# Test:47FD-070H-ANN
# end
# [336]Source:47FD-070H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH007-ANN
# end
# [337]Source:47AAH007-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48FALL2003-ANN
# end
# [338]Source:48FALL2003-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-058HH-ANN
# end
# [339]Source:47HSD-058HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:F201-CEM-CAL4
# end
# [340]Source:F201-CEM-CAL4, Conditions:['IOP-'], Total Alarms:1
# Test:47FD-023HH-ANN
# end
# [341]Source:47FD-023HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL1538B-ANN
# end
# [342]Source:47XL1538B-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-043HH-ANN
# end
# [343]Source:47HCD-043HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-019HH-ANN
# end
# [344]Source:47HID-019HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-064HH-ANN
# end
# [345]Source:47HCD-064HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PAL621-ANN
# end
# [346]Source:47PAL621-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LIC1504
# end
# [347]Source:47LIC1504, Conditions:['LO'], Total Alarms:1
# Test:47TI852
# end
# [348]Source:47TI852, Conditions:['HI'], Total Alarms:1
# Test:47VI700
# end
# [349]Source:47VI700, Conditions:['HI'], Total Alarms:1
# Test:47G121B-ANN
# end
# [350]Source:47G121B-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-017HH-ANN
# end
# [351]Source:47HID-017HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48TI001
# end
# [352]Source:48TI001, Conditions:['HI'], Total Alarms:1
# Test:47HSD-051H-ANN
# end
# [353]Source:47HSD-051H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-018H-ANN
# end
# [354]Source:47HID-018H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-033H-ANN
# end
# [355]Source:47FD-033H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-022HH-ANN
# end
# [356]Source:47FD-022HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FIC3102
# end
# [357]Source:47FIC3102, Conditions:['LO'], Total Alarms:1
# Test:47HSD-059HH-ANN
# end
# [358]Source:47HSD-059HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-001HH-ANN
# end
# [359]Source:47HCD-001HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:01XL037-ANN
# end
# [360]Source:01XL037-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH301-ANN
# end
# [361]Source:47AAH301-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-025H-ANN
# end
# [362]Source:47HSD-025H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-061H-ANN
# end
# [363]Source:47HCD-061H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-002H-ANN
# end
# [364]Source:47HCD-002H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AH012-ANN
# end
# [365]Source:47AH012-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-030H-ANN
# end
# [366]Source:47HSD-030H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI2086
# end
# [367]Source:47TI2086, Conditions:['HI'], Total Alarms:1
# Test:47HID-019H-ANN
# end
# [368]Source:47HID-019H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH2004-ANN
# end
# [369]Source:48AAH2004-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-081H-ANN
# end
# [370]Source:47HCD-081H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL3503A-ANN
# end
# [371]Source:47XL3503A-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47HCD-027HH-ANN
# end
# [372]Source:47HCD-027HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH008-ANN
# end
# [373]Source:47AAH008-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-005H-ANN
# end
# [374]Source:47HSD-005H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:01AAH004-ANN
# end
# [375]Source:01AAH004-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-024HH-ANN
# end
# [376]Source:47HSD-024HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-053HH-ANN
# end
# [377]Source:47HSD-053HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH006-ANN
# end
# [378]Source:48AAH006-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-059H-ANN
# end
# [379]Source:47HSD-059H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TIC2056
# end
# [380]Source:47TIC2056, Conditions:['LO'], Total Alarms:1
# Test:47HCD-004HH-ANN
# end
# [381]Source:47HCD-004HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL1544-ANN
# end
# [382]Source:47XL1544-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-029HH-ANN
# end
# [383]Source:47HCD-029HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-073H-ANN
# end
# [384]Source:47FD-073H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47G121A-ANN
# end
# [385]Source:47G121A-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47HCD-044H-ANN
# end
# [386]Source:47HCD-044H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI424
# end
# [387]Source:47TI424, Conditions:['HHH'], Total Alarms:1
# Test:47_AMPSA_PMCC2R
# end
# [388]Source:47_AMPSA_PMCC2R, Conditions:['IOP'], Total Alarms:1
# Test:48AAH2008-ANN
# end
# [389]Source:48AAH2008-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TDI1548
# end
# [390]Source:47TDI1548, Conditions:['LO'], Total Alarms:1
# Test:47HCD-062H-ANN
# end
# [391]Source:47HCD-062H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-014H-ANN
# end
# [392]Source:47FD-014H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-080HH-ANN
# end
# [393]Source:47HCD-080HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-011HH-ANN
# end
# [394]Source:47HCD-011HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH2003-ANN
# end
# [395]Source:48AAH2003-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-015HH-ANN
# end
# [396]Source:47HID-015HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-051HH-ANN
# end
# [397]Source:47HSD-051HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-034HH-ANN
# end
# [398]Source:47FD-034HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-006H-ANN
# end
# [399]Source:47HSD-006H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-022H-ANN
# end
# [400]Source:47FD-022H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI414E
# end
# [401]Source:47TI414E, Conditions:['HI'], Total Alarms:1
# Test:47FD-072H-ANN
# end
# [402]Source:47FD-072H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-029H-ANN
# end
# [403]Source:47HCD-029H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FIC013
# end
# [404]Source:47FIC013, Conditions:['HI'], Total Alarms:1
# Test:47AIT2015
# end
# [405]Source:47AIT2015, Conditions:['IOP-'], Total Alarms:1
# Test:47PAL706-ANN
# end
# [406]Source:47PAL706-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-062HH-ANN
# end
# [407]Source:47HCD-062HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-002HH-ANN
# end
# [408]Source:47HCD-002HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-045H-ANN
# end
# [409]Source:47HCD-045H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-070HH-ANN
# end
# [410]Source:47FD-070HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-030HH-ANN
# end
# [411]Source:47HSD-030HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FIC021
# end
# [412]Source:47FIC021, Conditions:['LO'], Total Alarms:1
# Test:47FD-021H-ANN
# end
# [413]Source:47FD-021H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LIC1505
# end
# [414]Source:47LIC1505, Conditions:['LO'], Total Alarms:1
# Test:47FD-034H-ANN
# end
# [415]Source:47FD-034H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:01XL032-ANN
# end
# [416]Source:01XL032-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL017A-ANN
# end
# [417]Source:47XL017A-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FIC1508
# end
# [418]Source:47FIC1508, Conditions:['HI'], Total Alarms:1
# Test:47HSD-031H-ANN
# end
# [419]Source:47HSD-031H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48HSD-004HH-ANN
# end
# [420]Source:48HSD-004HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-047HH-ANN
# end
# [421]Source:47HCD-047HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-080H-ANN
# end
# [422]Source:47HCD-080H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-026HH-ANN
# end
# [423]Source:47HCD-026HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI1711
# end
# [424]Source:47PI1711, Conditions:['LO'], Total Alarms:1
# Test:47XL1542-ANN
# end
# [425]Source:47XL1542-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-053H-ANN
# end
# [426]Source:47HSD-053H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH006-ANN
# end
# [427]Source:47AAH006-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI134
# end
# [428]Source:47TI134, Conditions:['HI'], Total Alarms:1
# Test:47HCD-011H-ANN
# end
# [429]Source:47HCD-011H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH2007-ANN
# end
# [430]Source:48AAH2007-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-065HH-ANN
# end
# [431]Source:47HCD-065HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL3503B-ANN
# end
# [432]Source:47XL3503B-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47HID-020H-ANN
# end
# [433]Source:47HID-020H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-012HH-ANN
# end
# [434]Source:47HCD-012HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-016HH-ANN
# end
# [435]Source:47HID-016HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI2082
# end
# [436]Source:47TI2082, Conditions:['IOP'], Total Alarms:1
# Test:47AI2015
# end
# [437]Source:47AI2015, Conditions:['IOP-'], Total Alarms:1
# Test:47PI2039C
# end
# [438]Source:47PI2039C, Conditions:['LLL'], Total Alarms:1
# Test:47PI2029B
# end
# [439]Source:47PI2029B, Conditions:['LLL'], Total Alarms:1
# Test:47HCD-004H-ANN
# end
# [440]Source:47HCD-004H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AI1503
# end
# [441]Source:47AI1503, Conditions:['IOP'], Total Alarms:1
# Test:47AIC1503
# end
# [442]Source:47AIC1503, Conditions:['IOP'], Total Alarms:1
# Test:47TI1003
# end
# [443]Source:47TI1003, Conditions:['LO'], Total Alarms:1
# Test:47FI1567
# end
# [444]Source:47FI1567, Conditions:['HI'], Total Alarms:1
# Test:47TI414L
# end
# [445]Source:47TI414L, Conditions:['LO'], Total Alarms:1
# Test:47FD-033HH-ANN
# end
# [446]Source:47FD-033HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-007HH-ANN
# end
# [447]Source:47HSD-007HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48HSD-004H-ANN
# end
# [448]Source:48HSD-004H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-081HH-ANN
# end
# [449]Source:47HCD-081HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-017H-ANN
# end
# [450]Source:47HID-017H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-068H-ANN
# end
# [451]Source:47FD-068H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48AAH2006-ANN
# end
# [452]Source:48AAH2006-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-018HH-ANN
# end
# [453]Source:47HID-018HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-065H-ANN
# end
# [454]Source:47HCD-065H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AI2001
# end
# [455]Source:47AI2001, Conditions:['IOP-'], Total Alarms:1
# Test:47LIC3205
# end
# [456]Source:47LIC3205, Conditions:['HI'], Total Alarms:1
# Test:47PAL620-ANN
# end
# [457]Source:47PAL620-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI2039A
# end
# [458]Source:47PI2039A, Conditions:['LLL'], Total Alarms:1
# Test:48LIC018
# end
# [459]Source:48LIC018, Conditions:['LO'], Total Alarms:0
# Test:47PI636
# end
# [460]Source:47PI636, Conditions:['HI'], Total Alarms:1
# Test:47FD-071H-ANN
# end
# [461]Source:47FD-071H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-006HH-ANN
# end
# [462]Source:47HSD-006HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-052H-ANN
# end
# [463]Source:47HSD-052H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HID-015H-ANN
# end
# [464]Source:47HID-015H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI2039B
# end
# [465]Source:47PI2039B, Conditions:['LLL'], Total Alarms:1
# Test:47PIC1504
# end
# [466]Source:47PIC1504, Conditions:['HI'], Total Alarms:1
# Test:47AAH016-ANN
# end
# [467]Source:47AAH016-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-079H-ANN
# end
# [468]Source:47HCD-079H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47LI950
# end
# [469]Source:47LI950, Conditions:['LO'], Total Alarms:1
# Test:47HCD-079HH-ANN
# end
# [470]Source:47HCD-079HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-071HH-ANN
# end
# [471]Source:47FD-071HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI2076
# end
# [472]Source:47TI2076, Conditions:['HI'], Total Alarms:1
# Test:48TIC016
# end
# [473]Source:48TIC016, Conditions:['LO'], Total Alarms:1
# Test:47FD-073HH-ANN
# end
# [474]Source:47FD-073HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-003HH-ANN
# end
# [475]Source:47HCD-003HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI414A
# end
# [476]Source:47TI414A, Conditions:['LO'], Total Alarms:1
# Test:47FD-010H-ANN
# end
# [477]Source:47FD-010H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI856
# end
# [478]Source:47TI856, Conditions:['HI'], Total Alarms:1
# Test:47TI414I
# end
# [479]Source:47TI414I, Conditions:['LO'], Total Alarms:1
# Test:47HSD-052HH-ANN
# end
# [480]Source:47HSD-052HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-045HH-ANN
# end
# [481]Source:47HCD-045HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI414P
# end
# [482]Source:47TI414P, Conditions:['LO'], Total Alarms:1
# Test:47HSD-049H-ANN
# end
# [483]Source:47HSD-049H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI1505
# end
# [484]Source:47TI1505, Conditions:['HI'], Total Alarms:1
# Test:47EM304B-ANN
# end
# [485]Source:47EM304B-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-024H-ANN
# end
# [486]Source:47HSD-024H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH014-ANN
# end
# [487]Source:47AAH014-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-044HH-ANN
# end
# [488]Source:47HCD-044HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-049HH-ANN
# end
# [489]Source:47HSD-049HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TAIL_DUTY
# end
# [490]Source:47TAIL_DUTY, Conditions:['IOP'], Total Alarms:1
# Test:47_AMPSC_PMCC2R
# end
# [491]Source:47_AMPSC_PMCC2R, Conditions:['IOP'], Total Alarms:1
# Test:47HCD-061HH-ANN
# end
# [492]Source:47HCD-061HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48HSD-003HH-ANN
# end
# [493]Source:48HSD-003HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-005HH-ANN
# end
# [494]Source:47HSD-005HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-035H-ANN
# end
# [495]Source:47FD-035H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HCD-063H-ANN
# end
# [496]Source:47HCD-063H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47HSD-050H-ANN
# end
# [497]Source:47HSD-050H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:01XL031-ANN
# end
# [498]Source:01XL031-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47PI2029C
# end
# [499]Source:47PI2029C, Conditions:['LLL'], Total Alarms:1
# Test:47FIC1505
# end
# [500]Source:47FIC1505, Conditions:['LO'], Total Alarms:1
# Test:47TI1591
# end
# [501]Source:47TI1591, Conditions:['LO'], Total Alarms:1
# Test:47HSD-007H-ANN
# end
# [502]Source:47HSD-007H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48HSD-003H-ANN
# end
# [503]Source:48HSD-003H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47XL1557D-ANN
# end
# [504]Source:47XL1557D-ANN, Conditions:['ALM'], Total Alarms:0
# Test:48AAH009-ANN
# end
# [505]Source:48AAH009-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH013-ANN
# end
# [506]Source:47AAH013-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47TI443
# end
# [507]Source:47TI443, Conditions:['HH'], Total Alarms:0
# Test:47FD-014HH-ANN
# end
# [508]Source:47FD-014HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47AAH010-ANN
# end
# [509]Source:47AAH010-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47UALL802-ANN
# end
# [510]Source:47UALL802-ANN, Conditions:['ALM'], Total Alarms:1
# Test:47FD-023H-ANN
# end
# [511]Source:47FD-023H-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48XL012-ANN
# end
# [512]Source:48XL012-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47TI3313
# end
# [513]Source:47TI3313, Conditions:['LO'], Total Alarms:1
# Test:47HSD-031HH-ANN
# end
# [514]Source:47HSD-031HH-ANN, Conditions:['ALM'], Total Alarms:1
# Test:48TIC008
# end
# [515]Source:48TIC008, Conditions:['LO'], Total Alarms:1
# Test:47TI2111B
# end
# [516]Source:47TI2111B, Conditions:['LLL'], Total Alarms:0
# Test:47TI414C
# end
# [517]Source:47TI414C, Conditions:['LO'], Total Alarms:1
# Test:47XL605-ANN
# end
# [518]Source:47XL605-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1529-ANN
# end
# [519]Source:47XL1529-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47G17B-ANN
# end
# [520]Source:47G17B-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1558-ANN
# end
# [521]Source:47XL1558-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47TI1510
# end
# [522]Source:47TI1510, Conditions:['HI'], Total Alarms:0
# Test:47XL1530-ANN
# end
# [523]Source:47XL1530-ANN, Conditions:['ALM'], Total Alarms:0
# Test:01XL036-ANN
# end
# [524]Source:01XL036-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1527-ANN
# end
# [525]Source:47XL1527-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47TI616
# end
# [526]Source:47TI616, Conditions:['HI'], Total Alarms:0
# Test:47XL604-ANN
# end
# [527]Source:47XL604-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1559-ANN
# end
# [528]Source:47XL1559-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47TI260
# end
# [529]Source:47TI260, Conditions:['LO'], Total Alarms:0
# Test:47XL602-ANN
# end
# [530]Source:47XL602-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1524-ANN
# end
# [531]Source:47XL1524-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47FIC2007
# end
# [532]Source:47FIC2007, Conditions:['HI'], Total Alarms:0
# Test:47FIC2008
# end
# [533]Source:47FIC2008, Conditions:['HI'], Total Alarms:0
# Test:47XL603-ANN
# end
# [534]Source:47XL603-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47TI275
# end
# [535]Source:47TI275, Conditions:['LO'], Total Alarms:0
# Test:47XL1528-ANN
# end
# [536]Source:47XL1528-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47PI860
# end
# [537]Source:47PI860, Conditions:['LO'], Total Alarms:0
# Test:47XL1560-ANN
# end
# [538]Source:47XL1560-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47XL1535-ANN
# end
# [539]Source:47XL1535-ANN, Conditions:['ALM'], Total Alarms:0
# Test:47PI055
# end
# [540]Source:47PI055, Conditions:['LL'], Total Alarms:0
# Test:47XL1523-ANN
# end
# [541]Source:47XL1523-ANN, Conditions:['ALM'], Total Alarms:0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968360 entries, 0 to 968359
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   MachineName  968360 non-null  object
#  1   SourceName   968360 non-null  object
#  2   Message      968360 non-null  object
#  3   Condition    968360 non-null  object
#  4   MessageType  968360 non-null  object
#  5   StartTime    968360 non-null  datetime64[ns]
#  6   EndTime      968360 non-null  datetime64[ns]
#  7   EndMessage   968360 non-null  object
#  8   TimeDelta    968360 non-null  float64
#  9   Year-Month   968360 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(7)
# memory usage: 73.9+ MB
# >>Conversion from records to alarms is complete. Outputfile : J:/GENEL MUDURLUK/ARGE MUDURLUGU/ALGORİTMA-VE-YAZILIMSAL-ÇÖZÜM-GELİŞTİRME/1. PROJELER/10. KUTEM/3- VERİLER/Alarms/Alarms/alarms/alarms_/alarm_out.csv, Info : None

# %%
#df_alarms = pd.read_csv("/Users/hamzagorgulu/Desktop/thesis/From Waris (EdgeAlarm)/Datasets/records2alarm/alarms/alarms_fname.csv")
# you should convert the existing alarm in this notebook, not the imported one above. It was a trying

# %%
df_alarms.head()
# Out:
#   MachineName SourceName                                         Message  \
# 0      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.5 C VEL-
# 1      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.8 C VEL-
# 2      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.9 C VEL-
# 3      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.5 C VEL-
# 4      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL-
#
#   Condition MessageType            StartTime              EndTime  \
# 0      VEL-  Activation  2020-03-01 00:00:03  2020-03-01 00:00:05
# 1      VEL-  Activation  2020-03-01 00:00:07  2020-03-01 00:00:08
# 2      VEL-  Activation  2020-03-01 00:00:10  2020-03-01 00:00:11
# 3      VEL-  Activation  2020-03-01 00:00:18  2020-03-01 00:00:20
# 4      VEL-  Activation  2020-03-01 00:00:22  2020-03-01 00:00:23
#
#                                           EndMessage  TimeDelta Year-Month  \
# 0  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.3 C VEL-...        2.0  (2020, 3)
# 1  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.4 C VEL-...        1.0  (2020, 3)
# 2  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL-...        1.0  (2020, 3)
# 3  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.2 C VEL-...        2.0  (2020, 3)
# 4  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.2 C VEL-...        1.0  (2020, 3)
#
#    Day
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
# create Day column from the dataset
df_alarms['Day'] =  df_alarms["StartTime"].apply(lambda x: int(x.split(" ")[0][-2:]))
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 697810    6
# 697811    6
# 697812    6
# 697813    6
# 697814    2
# Name: Day, Length: 697815, dtype: int64

# %%
df_alarms["Day"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 697810    6
# 697811    6
# 697812    6
# 697813    6
# 697814    2
# Name: Day, Length: 697815, dtype: int64

# %%
df_alarms["StartTime"][0]
# Out:
# '2020-03-01 00:00:03'

# %%
df_alarms.head()
# Out:
#   MachineName SourceName                                         Message  \
# 0      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.5 C VEL+
# 1      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.4 C VEL+
# 2      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.3 C VEL+
# 3      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.3 C VEL+
# 4      PHD47B  48TIC2026  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.3 C VEL+
#
#   Condition MessageType           StartTime             EndTime  \
# 0      VEL+  Activation 2019-08-01 00:00:05 2019-08-01 00:00:07
# 1      VEL+  Activation 2019-08-01 00:00:09 2019-08-01 00:00:10
# 2      VEL+  Activation 2019-08-01 00:00:14 2019-08-01 00:00:15
# 3      VEL+  Activation 2019-08-01 00:00:17 2019-08-01 00:00:19
# 4      VEL+  Activation 2019-08-01 00:00:22 2019-08-01 00:00:23
#
#                                           EndMessage  TimeDelta Year-Month
# 0  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.8 C VEL+...        2.0  (2019, 8)
# 1  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL+...        1.0  (2019, 8)
# 2  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL+...        1.0  (2019, 8)
# 3  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL+...        2.0  (2019, 8)
# 4  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.6 C VEL+...        1.0  (2019, 8)
